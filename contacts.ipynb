# %% [markdown]
# <a href="https://colab.research.google.com/github/Hefot-Ahmed/Pandas-Projects/blob/main/contacts.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
contracts = {
    'name': ['Bart', 'Lisa', 'Homer', 'Marge'],
    'age': [10, 8, 39, 36],
    'phone_number': [9395551113, 9395551114, 9395551115, 9395551116],
    'astrological_sign': ['Taurus', 'Virgo', 'Taurus', 'Pisces'],
}

df = pd.DataFrame(contracts)
print(df)
# Out:
#     name  age  phone_number astrological_sign
# 0   Bart   10    9395551113            Taurus
# 1   Lisa    8    9395551114             Virgo
# 2  Homer   39    9395551115            Taurus
# 3  Marge   36    9395551116            Pisces
