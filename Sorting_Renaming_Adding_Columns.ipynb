# %% [markdown]
# <a href="https://colab.research.google.com/github/Hefot-Ahmed/Pandas-Projects/blob/main/Sorting_Renaming_Adding_Columns.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# App data
app_data = {
  'app_name': [
    'YouTube', 'TikTok', 'Instagram', 'Spotify', 'Duolingo',
    'Twitter', 'Headspace', 'Discord', 'Depop'
  ],
  'category': [
    'Video', 'Social Media', 'Social Media', 'Music', 'Education',
    'Social Media', 'Health', 'Communication', 'Shopping'
  ],
  'rating': [
    4.7, 4.6, 4.5, 4.6, 4.7,
    4.3, None, 4.7, 4.4
  ],
  'downloads_millions': [
    5000, 3000, 3500, 2000, None,
    1500, 500, 600, 200
  ]
}

# Create the DataFrame
apps = pd.DataFrame(app_data)
sort_ratings = apps.sort_values(by='rating', ascending=False)
print(sort_ratings)
# Out:
#     app_name       category  rating  downloads_millions
# 0    YouTube          Video     4.7              5000.0
# 4   Duolingo      Education     4.7                 NaN
# 7    Discord  Communication     4.7               600.0
# 1     TikTok   Social Media     4.6              3000.0
# 3    Spotify          Music     4.6              2000.0
# 2  Instagram   Social Media     4.5              3500.0
# 8      Depop       Shopping     4.4               200.0
# 5    Twitter   Social Media     4.3              1500.0
# 6  Headspace         Health     NaN               500.0

# %%
import pandas as pd

# App data
app_data = {
  'app_name': [
    'YouTube', 'TikTok', 'Instagram', 'Spotify', 'Duolingo',
    'Twitter', 'Headspace', 'Discord', 'Depop'
  ],
  'category': [
    'Video', 'Social Media', 'Social Media', 'Music', 'Education',
    'Social Media', 'Health', 'Communication', 'Shopping'
  ],
  'rating': [
    4.7, 4.6, 4.5, 4.6, 4.7,
    4.3, None, 4.7, 4.4
  ],
  'downloads_millions': [
    5000, 3000, 3500, 2000, None,
    1500, 500, 600, 200
  ]
}

# Create the DataFrame
apps = pd.DataFrame(app_data)
rename_name = apps.rename(columns={'app_name': 'name'})
print(rename_name)
# Out:
#         name       category  rating  downloads_millions
# 0    YouTube          Video     4.7              5000.0
# 1     TikTok   Social Media     4.6              3000.0
# 2  Instagram   Social Media     4.5              3500.0
# 3    Spotify          Music     4.6              2000.0
# 4   Duolingo      Education     4.7                 NaN
# 5    Twitter   Social Media     4.3              1500.0
# 6  Headspace         Health     NaN               500.0
# 7    Discord  Communication     4.7               600.0
# 8      Depop       Shopping     4.4               200.0

# %%
import pandas as pd

# App data
app_data = {
  'app_name': [
    'YouTube', 'TikTok', 'Instagram', 'Spotify',
    'Twitter'
  ],
  'category': [
    'Video', 'Social Media', 'Social Media', 'Music',
    'Social Media'
  ]
}

# Create the DataFrame
apps = pd.DataFrame(app_data)
apps['downloaded'] = [True, True, False, False, False]

print(apps)
# Out:
#     app_name      category  downloaded
# 0    YouTube         Video        True
# 1     TikTok  Social Media        True
# 2  Instagram  Social Media       False
# 3    Spotify         Music       False
# 4    Twitter  Social Media       False
